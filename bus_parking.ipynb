# %%
import pymongo
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgresql@104.199.52.163:5432/opendata')

# %%
client = pymongo.MongoClient('mongodb+srv://angers:sregna@clusterangers-7bjup.gcp.mongodb.net/test?retryWrites=true')

# %%
client.list_database_names()
# Out:
# ['Traffic', 'admin', 'local']

# %%
db = client['Traffic']
db.list_collection_names()
# Out:
# ['busTraffic', 'parkingTraffic']

# %%
print(db['busTraffic'].estimated_document_count())
docs = [x['records'] for x in db['busTraffic'].find().limit(1)]
fields = [x['fields'] for x in docs[0]]
bt = pd.DataFrame(fields)
print(bt.shape)
bt.head()
# Out:
# 774
# (10, 21)
#    cap               coordonnees                     dest  ecart  etat  \
# 0  243  [47.485893, -0.51255723]      TRELAZE QUANTINIERE      0  TDEP
# 1  337  [47.465045, -0.55945135]           ST MARTIN DU F      0  HLPS
# 2   95  [47.471121, -0.53121436]                   ZI EST    143  LIGN
# 3  232  [47.468818, -0.55832905]            SAINTE GEMMES    713  LIGN
# 4  233  [47.465946, -0.59877727]  LAC DE MAINE - L'HOIRIE    338  LIGN
#
#                       harret  idarret  iddesserte    idligne  idparcours  \
# 0  2019-04-12T15:20:00+00:00  1214154   268611585  268435458   268611584
# 1  2019-04-12T15:30:00+00:00  1215437   270807297  268435492   270807296
# 2  2019-04-12T15:15:18+00:00  1214308   268840755  268435462   268840704
# 3  2019-04-12T15:16:14+00:00  1215795   269200411  268435467   269200384
# 4  2019-04-12T15:15:06+00:00  1214646   269168923  268435467   269168896
#
#     ...     mnemoarret mnemoligne          nomarret  \
# 0   ...       BANCSTMA         02          BANCHAIS
# 1   ...       GARESEMA         36  GARES SEMARD SUB
# 2   ...       CIEST.-E         06        FRATELLINI
# 3   ...       ACADEMIE         11          ACADEMIE
# 4   ...       LEDENIER         11       LES DENIERS
#
#                            nomligne  novh numarret    sv        type       x  \
# 0     ST SYLVAIN BANCHAIS <>TRELAZE   201    20610  0202  GX 427 Hyb  385339
# 1         ST MARTIN St JEAN <> GARE  3274    21525  3611  MAN STARTE  381722
# 2           BOUCHEMAINE <> Z I  EST   423    23398  0608    OMNICITY  383874
# 3  LAC MAINE <> STE GEMMES CL ANJOU   443   913399  1103    OMNICITY  381822
# 4  LAC MAINE <> STE GEMMES CL ANJOU   449     6046  1125    OMNICITY  378763
#
#          y
# 0  2280145
# 1  2277958
# 2  2278555
# 3  2278374
# 4  2278168
#
# [5 rows x 21 columns]

# %%
bt.dtypes
# Out:
# cap             int64
# coordonnees    object
# dest           object
# ecart           int64
# etat           object
# harret         object
# idarret         int64
# iddesserte      int64
# idligne         int64
# idparcours      int64
# idvh            int64
# mnemoarret     object
# mnemoligne     object
# nomarret       object
# nomligne       object
# novh           object
# numarret        int64
# sv             object
# type           object
# x               int64
# y               int64
# dtype: object

# %% [markdown]
# ### Parking

# %%
db['parkingTraffic'].estimated_document_count()
# Out:
# 760

# %%
records = []
for x in db['parkingTraffic'].find():
    for record in x['records']:
        f = record['fields']
        f['record_timestamp'] = record['record_timestamp']
        records.append(f)

pt = pd.DataFrame(records)
print(pt.shape)
pt.head()
# Out:
# (7600, 3)
#    disponible                nom           record_timestamp
# 0          97         Republique  2019-04-12T15:17:00+00:00
# 1          19          Bressigny  2019-04-12T15:17:00+00:00
# 2          47  Mitterrand Rennes  2019-04-12T15:17:00+00:00
# 3         311       Saint Laud 2  2019-04-12T15:17:00+00:00
# 4          20         Ralliement  2019-04-12T15:17:00+00:00

# %%
pt.columns = ['Disponible','Nom','Date']
pt['Date'] = pd.to_datetime(pt['Date'])
pt.head()
# Out:
#    Disponible                Nom                Date
# 0          97         Republique 2019-04-12 15:17:00
# 1          19          Bressigny 2019-04-12 15:17:00
# 2          47  Mitterrand Rennes 2019-04-12 15:17:00
# 3         311       Saint Laud 2 2019-04-12 15:17:00
# 4          20         Ralliement 2019-04-12 15:17:00

# %%
pt.dtypes
# Out:
# Disponible             int64
# Nom                   object
# Date          datetime64[ns]
# dtype: object

# %% [markdown]
# To the postgres database

# %%
pt.to_sql('parking', engine, index=False, if_exists='replace')

# %% [markdown]
# #### Coordinates

# %%
parking_csv = pd.read_csv('pv_equip_parking.csv', sep=';')
print(parking_csv.shape)
parking_csv.head()
# Out:
# (18, 22)
#                        NOM EXPLOITANT  ADR_NUM                 ADR_LIBVOI  \
# 0  Parking Berges de Maine      ALTER       26  ALLÉE FRANÇOIS MITTERRAND
# 1           Parking Larrey      ALTER       26  ALLÉE FRANÇOIS MITTERRAND
# 2          Parking Molière      ALTER       37                 RUE THIERS
# 3     Parking Poissonnerie      ALTER        7            RUE PLANTAGENÊT
# 4          Parking Leclerc      ALTER       14       BOULEVARD BESSONNEAU
#
#   NOM_COMMUNE  ID_EQUIP       ID_PARKING  \
# 0      ANGERS      2524  Berges De Maine
# 1      ANGERS      7550           Larrey
# 2      ANGERS      2089          Moliere
# 3      ANGERS      2574     Poissonnerie
# 4      ANGERS      2275          Leclerc
#
#                                            Geo Shape  \
# 0  {"type": "Point", "coordinates": [-0.549642004...
# 1  {"type": "Point", "coordinates": [-0.554951239...
# 2  {"type": "Point", "coordinates": [-0.554276891...
# 3  {"type": "Point", "coordinates": [-0.555937486...
# 4  {"type": "Point", "coordinates": [-0.546056082...
#
#                         Geo Point                       MOYENS_ACCES  \
# 0  47.4791055266, -0.549642004596      AVENUE DES DROITS DE  L'HOMME
# 1  47.4806370511, -0.554951239998                         RUE LARREY
# 2  47.4746632156, -0.554276891798                         RUE THIERS
# 3  47.4732815436, -0.555937486434                                NaN
# 4     47.47144192, -0.54605608257  PLACE LECLERC / PALAIS DE JUSTICE
#
#      ...     NB_PLACES NB_VELO_SECUR  NB_PLACES_PMR  ACCESSIBILITE  \
# 0    ...         305.0           0.0            7.0          24-24
# 1    ...          28.0           0.0            2.0          24-24
# 2    ...         416.0          38.0            9.0          24-24
# 3    ...           NaN           NaN            NaN            NaN
# 4    ...         235.0           0.0            4.0          24-24
#
#    HORAIRES_OUVERTURE HORAIRES_FERMETURE FERMETURE_EXCEPTION  \
# 0               07:00              00:00                 NaN
# 1                 NaN                NaN                 NaN
# 2               07:00              20:00                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN     SAM 00:00-17:00
#
#   HORAIRES_EXCEPTION      THEME SOUS_THEME
# 0                NaN  TRANSPORT    PARKING
# 1                NaN  TRANSPORT    PARKING
# 2                NaN  TRANSPORT    PARKING
# 3                NaN  TRANSPORT    PARKING
# 4                NaN  TRANSPORT    PARKING
#
# [5 rows x 22 columns]

# %%
parking_csv.columns
# Out:
# Index(['NOM', 'EXPLOITANT', 'ADR_NUM', 'ADR_LIBVOI', 'NOM_COMMUNE', 'ID_EQUIP',
#        'ID_PARKING', 'Geo Shape', 'Geo Point', 'MOYENS_ACCES', 'GPL',
#        'HAUTEUR_MAX', 'NB_PLACES', 'NB_VELO_SECUR', 'NB_PLACES_PMR',
#        'ACCESSIBILITE', 'HORAIRES_OUVERTURE', 'HORAIRES_FERMETURE',
#        'FERMETURE_EXCEPTION', 'HORAIRES_EXCEPTION', 'THEME', 'SOUS_THEME'],
#       dtype='object')

# %%
parking = parking_csv[['ID_PARKING','Geo Point','NB_PLACES']]
parking.columns = ['parking','geo_point','places']
parking
# Out:
#               parking                       geo_point  places
# 0     Berges De Maine  47.4791055266, -0.549642004596   305.0
# 1              Larrey  47.4806370511, -0.554951239998    28.0
# 2             Moliere  47.4746632156, -0.554276891798   416.0
# 3        Poissonnerie  47.4732815436, -0.555937486434     NaN
# 4             Leclerc     47.47144192, -0.54605608257   235.0
# 5   Mitterrand Rennes   47.476608392, -0.550574131243   133.0
# 6    Mitterrand Maine  47.4772420234, -0.552025911935   151.0
# 7          Saint Laud  47.4644889197, -0.558943020692   450.0
# 8             Marengo  47.4648842682, -0.554823179984   305.0
# 9        Haras Public  47.4648996364, -0.553765416644   112.0
# 10       Saint Laud 2  47.4640438606, -0.560504672316   576.0
# 11          Maternite  47.4814546969, -0.554413623853    56.0
# 12        Confluences  47.4806753779, -0.554545651222    30.0
# 13          Bressigny   47.4673424818, -0.54934224087   172.0
# 14               Mail  47.4712547046, -0.544924904001   960.0
# 15         Ralliement  47.4712242886, -0.551806483237   432.0
# 16               Quai   47.472633062, -0.565068160204   180.0
# 17         Republique  47.4725623676, -0.554958380401   383.0

# %%
latlon = parking['geo_point'].str.split(',', expand=True)
parking['latitude'] = latlon[0]
parking['longitude'] = latlon[1]
parking
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#               parking                       geo_point  places       latitude  \
# 0     Berges De Maine  47.4791055266, -0.549642004596   305.0  47.4791055266
# 1              Larrey  47.4806370511, -0.554951239998    28.0  47.4806370511
# 2             Moliere  47.4746632156, -0.554276891798   416.0  47.4746632156
# 3        Poissonnerie  47.4732815436, -0.555937486434     NaN  47.4732815436
# 4             Leclerc     47.47144192, -0.54605608257   235.0    47.47144192
# 5   Mitterrand Rennes   47.476608392, -0.550574131243   133.0   47.476608392
# 6    Mitterrand Maine  47.4772420234, -0.552025911935   151.0  47.4772420234
# 7          Saint Laud  47.4644889197, -0.558943020692   450.0  47.4644889197
# 8             Marengo  47.4648842682, -0.554823179984   305.0  47.4648842682
# 9        Haras Public  47.4648996364, -0.553765416644   112.0  47.4648996364
# 10       Saint Laud 2  47.4640438606, -0.560504672316   576.0  47.4640438606
# 11          Maternite  47.4814546969, -0.554413623853    56.0  47.4814546969
# 12        Confluences  47.4806753779, -0.554545651222    30.0  47.4806753779
# 13          Bressigny   47.4673424818, -0.54934224087   172.0  47.4673424818
# 14               Mail  47.4712547046, -0.544924904001   960.0  47.4712547046
# 15         Ralliement  47.4712242886, -0.551806483237   432.0  47.4712242886
# 16               Quai   47.472633062, -0.565068160204   180.0   47.472633062
# 17         Republique  47.4725623676, -0.554958380401   383.0  47.4725623676
#
#            longitude
# 0    -0.549642004596
# 1    -0.554951239998
# 2    -0.554276891798
# 3    -0.555937486434
# 4     -0.54605608257
# 5    -0.550574131243
# 6    -0.552025911935
# 7    -0.558943020692
# 8    -0.554823179984
# 9    -0.553765416644
# 10   -0.560504672316
# 11   -0.554413623853
# 12   -0.554545651222
# 13    -0.54934224087
# 14   -0.544924904001
# 15   -0.551806483237
# 16   -0.565068160204
# 17   -0.554958380401

# %% [markdown]
# To the postgres database

# %%
parking.to_sql('parking_list', engine, index=False, if_exists='replace')

# %%
parking_full = pt.merge(parking, left_on='Nom', right_on='parking')
parking_full.drop('parking', axis=1, inplace=True)
parking_full.columns = ['disponible','nom','date','geo_point','max_places','latitude','longitude']
print(parking_full.shape)
parking_full.head()
# Out:
# (7600, 7)
#    disponible         nom                date                       geo_point  \
# 0          97  Republique 2019-04-12 15:17:00  47.4725623676, -0.554958380401
# 1         103  Republique 2019-04-12 15:24:00  47.4725623676, -0.554958380401
# 2         109  Republique 2019-04-12 15:28:00  47.4725623676, -0.554958380401
# 3         105  Republique 2019-04-12 15:33:00  47.4725623676, -0.554958380401
# 4         120  Republique 2019-04-12 15:48:00  47.4725623676, -0.554958380401
#
#    max_places       latitude         longitude
# 0       383.0  47.4725623676   -0.554958380401
# 1       383.0  47.4725623676   -0.554958380401
# 2       383.0  47.4725623676   -0.554958380401
# 3       383.0  47.4725623676   -0.554958380401
# 4       383.0  47.4725623676   -0.554958380401

# %% [markdown]
# To the postgres database

# %%
parking_full.to_sql('parking_full', engine, index=False, if_exists='replace')
